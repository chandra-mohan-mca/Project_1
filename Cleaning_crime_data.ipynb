# %%
import pandas as pd

# %%
crime_datas=pd.read_csv('Crime_movie_data.csv')

# %%
crime_datas
# Out:
#      Unnamed: 0                                         Movie_Name  Ratings  \
# 0             0                                            1. Trap      5.8
# 1             1                                       2. Riff Raff      5.8
# 2             2                                        3. Longlegs      6.6
# 3             3                       4. Pushpa: The Rule - Part 2      6.1
# 4             4                                       5. The Order      6.8
# ..          ...                                                ...      ...
# 579         579                           843. Runnin' from Wolves      7.2
# 580         580                            848. Nacida Para Vengar      8.0
# 581         581  873. Der Wien-Krimi: Blind ermittelt - Tod im ...      6.7
# 582         582                                    882. Mudo Kannu      7.2
# 583         583                       895. Las Hermanas Del Cartel      8.2
#
#     Voting_Counts Durations  Genre
# ...

# %%
crime_datas['Voting_Counts'] = crime_datas['Voting_Counts'].replace({'[()]': ''}, regex=True)

# %%
crime_datas
# Out:
#      Unnamed: 0                                         Movie_Name  Ratings  \
# 0             0                                            1. Trap      5.8
# 1             1                                       2. Riff Raff      5.8
# 2             2                                        3. Longlegs      6.6
# 3             3                       4. Pushpa: The Rule - Part 2      6.1
# 4             4                                       5. The Order      6.8
# ..          ...                                                ...      ...
# 579         579                           843. Runnin' from Wolves      7.2
# 580         580                            848. Nacida Para Vengar      8.0
# 581         581  873. Der Wien-Krimi: Blind ermittelt - Tod im ...      6.7
# 582         582                                    882. Mudo Kannu      7.2
# 583         583                       895. Las Hermanas Del Cartel      8.2
#
#     Voting_Counts Durations  Genre
# ...

# %%
crime_datas['Voting_Counts'] = crime_datas['Voting_Counts'].apply(
    lambda x: float(x.replace('K', '').replace('k', '')) * 1000 if 'K' in x or 'k' in x else x
)

# %%
crime_datas
# Out:
#      Unnamed: 0                                         Movie_Name  Ratings  \
# 0             0                                            1. Trap      5.8
# 1             1                                       2. Riff Raff      5.8
# 2             2                                        3. Longlegs      6.6
# 3             3                       4. Pushpa: The Rule - Part 2      6.1
# 4             4                                       5. The Order      6.8
# ..          ...                                                ...      ...
# 579         579                           843. Runnin' from Wolves      7.2
# 580         580                            848. Nacida Para Vengar      8.0
# 581         581  873. Der Wien-Krimi: Blind ermittelt - Tod im ...      6.7
# 582         582                                    882. Mudo Kannu      7.2
# 583         583                       895. Las Hermanas Del Cartel      8.2
#
#     Voting_Counts Durations  Genre
# ...

# %%
crime_datas['Voting_Counts']=crime_datas['Voting_Counts'].astype(int)

# %%
crime_datas
# Out:
#      Unnamed: 0                                         Movie_Name  Ratings  \
# 0             0                                            1. Trap      5.8
# 1             1                                       2. Riff Raff      5.8
# 2             2                                        3. Longlegs      6.6
# 3             3                       4. Pushpa: The Rule - Part 2      6.1
# 4             4                                       5. The Order      6.8
# ..          ...                                                ...      ...
# 579         579                           843. Runnin' from Wolves      7.2
# 580         580                            848. Nacida Para Vengar      8.0
# 581         581  873. Der Wien-Krimi: Blind ermittelt - Tod im ...      6.7
# 582         582                                    882. Mudo Kannu      7.2
# 583         583                       895. Las Hermanas Del Cartel      8.2
#
#      Voting_Counts Durations  Genre
# ...

# %%
import re

# %%
import pandas as pd
import re

# Sample data
#data = {'Duration': ['1h 58m', '2h 58m', '0h 45m', '3h 10m']}
#df = pd.DataFrame(data)

# Function to convert durations to minutes
def convert_to_minutes(Durations):
    hours = 0
    minutes = 0
    # Use regex to extract hours and minutes
    match = re.match(r'(?P<hours>\d+)h (?P<minutes>\d+)m', Durations)
    if match:
        hours = int(match.group('hours'))
        minutes = int(match.group('minutes'))
    # Convert to minutes (1 hour = 60 minutes)
    return hours * 60 + minutes

# Apply the conversion function to the 'Duration' column
crime_datas['Durations'] = crime_datas['Durations'].apply(convert_to_minutes)

# %%
crime_datas
# Out:
#      Unnamed: 0                                         Movie_Name  Ratings  \
# 0             0                                            1. Trap      5.8
# 1             1                                       2. Riff Raff      5.8
# 2             2                                        3. Longlegs      6.6
# 3             3                       4. Pushpa: The Rule - Part 2      6.1
# 4             4                                       5. The Order      6.8
# ..          ...                                                ...      ...
# 579         579                           843. Runnin' from Wolves      7.2
# 580         580                            848. Nacida Para Vengar      8.0
# 581         581  873. Der Wien-Krimi: Blind ermittelt - Tod im ...      6.7
# 582         582                                    882. Mudo Kannu      7.2
# 583         583                       895. Las Hermanas Del Cartel      8.2
#
#      Voting_Counts  Durations  Genre
# ...

# %%
crime_datas['Movie_Name'] = crime_datas['Movie_Name'].replace(r'^\d+\.\s*', '', regex=True)

# %%
crime_datas
# Out:
#      Unnamed: 0                                       Movie_Name  Ratings  \
# 0             0                                             Trap      5.8
# 1             1                                        Riff Raff      5.8
# 2             2                                         Longlegs      6.6
# 3             3                        Pushpa: The Rule - Part 2      6.1
# 4             4                                        The Order      6.8
# ..          ...                                              ...      ...
# 579         579                              Runnin' from Wolves      7.2
# 580         580                               Nacida Para Vengar      8.0
# 581         581  Der Wien-Krimi: Blind ermittelt - Tod im Palais      6.7
# 582         582                                       Mudo Kannu      7.2
# 583         583                          Las Hermanas Del Cartel      8.2
#
#      Voting_Counts  Durations  Genre
# 0           134000        105  Crime
# ...

# %%
crime_movie=crime_datas.drop(columns='Unnamed: 0')

# %%
crime_movie
# Out:
#                                           Movie_Name  Ratings  Voting_Counts  \
# 0                                               Trap      5.8         134000
# 1                                          Riff Raff      5.8           2200
# 2                                           Longlegs      6.6         181000
# 3                          Pushpa: The Rule - Part 2      6.1          55000
# 4                                          The Order      6.8          39000
# ..                                               ...      ...            ...
# 579                              Runnin' from Wolves      7.2             10
# 580                               Nacida Para Vengar      8.0              9
# 581  Der Wien-Krimi: Blind ermittelt - Tod im Palais      6.7             29
# 582                                       Mudo Kannu      7.2           2100
# 583                          Las Hermanas Del Cartel      8.2              5
#
#      Durations  Genre
# ...

# %%
crime_movie.loc[crime_movie['Voting_Counts'].idxmax()]
# Out:
# Movie_Name       Longlegs
# Ratings               6.6
# Voting_Counts      181000
# Durations             101
# Genre               Crime
# Name: 2, dtype: object

# %%
crime_movie.to_csv('Crime_movie_datas.csv')
