# %%
import pandas as pd

# %%
data=pd.read_csv('Thriller_movie_datas.csv')

# %%
data.iloc[1:20]
# Out:
#                    Movie_Name  Ratings  Voting_Counts  Durations     Genre
# 1                     Heretic      7.0         127000        111  Thriller
# 2                    Twisters      6.5         163000        122  Thriller
# 3                    Conclave      7.4         139000          0  Thriller
# 4                        Trap      5.8         134000        105  Thriller
# 5                    Babygirl      6.0          50000        114  Thriller
# 6       Venom: The Last Dance      6.0         112000        110  Thriller
# 7                    Longlegs      6.6         181000        101  Thriller
# 8   Pushpa: The Rule - Part 2      6.1          55000        201  Thriller
# 9                    Presence      6.1          19000         84  Thriller
# 10                Blink Twice      6.5         103000        102  Thriller
# 11                  The Order      6.8          39000        116  Thriller
# ...

# %%
data1=pd.read_csv('Action_movie_datas.csv')
data1
# Out:
#                     Movie_Name  Ratings  Voting_Counts  Durations   Genre
# 0            Kraven the Hunter      5.5          49000        127  Action
# 1                     Twisters      6.5         163000        122  Action
# 2                 Gladiator II      6.5         221000        148  Action
# 3         Sonic the Hedgehog 3      6.9          55000        110  Action
# 4        Venom: The Last Dance      6.0         112000        110  Action
# ..                         ...      ...            ...        ...     ...
# 793            Lealtad o Morir      8.2              9         87  Action
# 794  PW V: Tears of the Fallen      8.2             11          0  Action
# 795                    Gadha17      8.0             11         90  Action
# 796      Bring Back the Colour      5.9              7          0  Action
# 797                 Killer Lee      1.9              9         87  Action
#
# [798 rows x 5 columns]

# %%
data2=pd.read_csv('Adventure_movie_datas.csv')
data2
# Out:
#                                           Movie_Name  Ratings  Voting_Counts  \
# 0                              Mufasa: The Lion King      6.6          54000
# 1                                            Moana 2      6.6          95000
# 2                                               Flow      7.9          66000
# 3                                           Twisters      6.5         163000
# 4                                       Gladiator II      6.5         221000
# ..                                               ...      ...            ...
# 266                                     Benjamin Bat      8.1             28
# 267                                            Z-Mom      4.7             43
# 268                                Mesken (Messuage)      7.5             37
# 269                             Rocky and Bullwinkle      9.1             12
# 270  Dikkie Dik 2: Een Nieuwe Vriend voor Dikkie Dik      7.4             72
#
#      Durations      Genre
# ...

# %%
data3=pd.read_csv('Comedy_movie_datas.csv')
data3
# Out:
#                     Movie_Name  Ratings  Voting_Counts  Durations   Genre
# 0                        Anora      7.5         168000        139  Comedy
# 1                      Moana 2      6.6          95000        100  Comedy
# 2                    Riff Raff      5.8           2200        103  Comedy
# 3         Sonic the Hedgehog 3      6.9          55000        110  Comedy
# 4                  A Real Pain      7.1          81000         90  Comedy
# ...                        ...      ...            ...        ...     ...
# 1318  Kak ya vstretil eyo mamu      4.3             41         89  Comedy
# 1319                 Trip-Tych      6.9             28         80  Comedy
# 1320              Bhale Unnade      9.0           3100        137  Comedy
# 1321      Happy Birthday to Me      8.3             88        112  Comedy
# 1322              Cuadrilátero      7.5              8         81  Comedy
#
# [1323 rows x 5 columns]

# %%
data4=pd.read_csv('Crime_movie_datas.csv')
data4
# Out:
#                                           Movie_Name  Ratings  Voting_Counts  \
# 0                                               Trap      5.8         134000
# 1                                          Riff Raff      5.8           2200
# 2                                           Longlegs      6.6         181000
# 3                          Pushpa: The Rule - Part 2      6.1          55000
# 4                                          The Order      6.8          39000
# ..                                               ...      ...            ...
# 579                              Runnin' from Wolves      7.2             10
# 580                               Nacida Para Vengar      8.0              9
# 581  Der Wien-Krimi: Blind ermittelt - Tod im Palais      6.7             29
# 582                                       Mudo Kannu      7.2           2100
# 583                          Las Hermanas Del Cartel      8.2              5
#
#      Durations  Genre
# ...

# %%
data5=pd.read_csv('Horror_movie_datas.csv')
data5
# Out:
#            Movie_Name  Ratings  Voting_Counts  Durations   Genre
# 0       The Substance      7.3         288000        141  Horror
# 1           Nosferatu      7.3         184000        132  Horror
# 2             Heretic      7.0         127000        111  Horror
# 3                Trap      5.8         134000        105  Horror
# 4            Longlegs      6.6         181000        101  Horror
# ..                ...      ...            ...        ...     ...
# 964  Gentleman Caller      8.5              9        103  Horror
# 965          Cintihar      2.5             11         77  Horror
# 966             Yagna      5.9           1100        131  Horror
# 967    Once Passed On      6.6              6         91  Horror
# 968             Rahha      2.7             13        135  Horror
#
# [969 rows x 5 columns]

# %%
imdb_movie_data_2024 = pd.concat([data, data1,data2,data3,data4,data5],ignore_index=True)

# %%
imdb_movie_datas
# Out:
#             Movie_Name  Ratings  Voting_Counts  Durations     Genre
# 0    Kraven the Hunter      5.5          49000        127  Thriller
# 1              Heretic      7.0         127000        111  Thriller
# 2             Twisters      6.5         163000        122  Thriller
# 3             Conclave      7.4         139000          0  Thriller
# 4                 Trap      5.8         134000        105  Thriller
# ..                 ...      ...            ...        ...       ...
# 964   Gentleman Caller      8.5              9        103    Horror
# 965           Cintihar      2.5             11         77    Horror
# 966              Yagna      5.9           1100        131    Horror
# 967     Once Passed On      6.6              6         91    Horror
# 968              Rahha      2.7             13        135    Horror
#
# [5109 rows x 5 columns]

# %%
imdb_movie_datas.tail(50)
# Out:
#                                 Movie_Name  Ratings  Voting_Counts  Durations  \
# 919       Biswas Villa-An Unfinished Story      8.6             21          0
# 920                   Laberinto de sombras      6.7              7        110
# 921                                    FPS      3.9             17          0
# 922                               The Clot      2.8             27         79
# 923             The Monsters Under Our Bed      5.9             11        127
# 924                           Hantu Polong      3.0              8         90
# 925                    Sobe: Sakalli Bebek      5.0             17         86
# 926                  New Tokyo Poltergeist      5.3              7         88
# 927                               Peccatum      1.8             21         68
# 928                         Unwelcome Home      7.6              6         75
# 929          Where the Mountain Women Sing      5.9              9          0
# ...

# %%
imdb_movie_datas.shape
# Out:
# (5109, 5)

# %%
imdb_movie_datas.isnull().sum()
# Out:
# Movie_Name       0
# Ratings          0
# Voting_Counts    0
# Durations        0
# Genre            0
# dtype: int64

# %%
imdb_movie_datas.duplicated().sum()
# Out:
# 0

# %%
imdb_movie_datas
# Out:
#                       Movie_Name  Ratings  Voting_Counts  Durations     Genre
# 0              Kraven the Hunter      5.5          49000        127  Thriller
# 1                        Heretic      7.0         127000        111  Thriller
# 2                       Twisters      6.5         163000        122  Thriller
# 3                       Conclave      7.4         139000          0  Thriller
# 4                           Trap      5.8         134000        105  Thriller
# ...                          ...      ...            ...        ...       ...
# 965                     Cintihar      2.5             11         77    Horror
# 966                        Yagna      5.9           1100        131    Horror
# 967               Once Passed On      6.6              6         91    Horror
# 968                        Rahha      2.7             13        135    Horror
# Voting_Counts                  6      6.0              6          6         6
#
# [5110 rows x 5 columns]

# %%
imdb_movie_datas.drop('Voting_Counts')
# Out:
#             Movie_Name  Ratings  Voting_Counts  Durations     Genre
# 0    Kraven the Hunter      5.5          49000        127  Thriller
# 1              Heretic      7.0         127000        111  Thriller
# 2             Twisters      6.5         163000        122  Thriller
# 3             Conclave      7.4         139000          0  Thriller
# 4                 Trap      5.8         134000        105  Thriller
# ..                 ...      ...            ...        ...       ...
# 964   Gentleman Caller      8.5              9        103    Horror
# 965           Cintihar      2.5             11         77    Horror
# 966              Yagna      5.9           1100        131    Horror
# 967     Once Passed On      6.6              6         91    Horror
# 968              Rahha      2.7             13        135    Horror
#
# [5109 rows x 5 columns]

# %%
imdb_movie_datas.tail()
# Out:
#                    Movie_Name  Ratings  Voting_Counts  Durations   Genre
# 965                  Cintihar      2.5             11         77  Horror
# 966                     Yagna      5.9           1100        131  Horror
# 967            Once Passed On      6.6              6         91  Horror
# 968                     Rahha      2.7             13        135  Horror
# Voting_Counts               6      6.0              6          6       6

# %%
imdb_movie_data=imdb_movie_datas.drop('Voting_Counts')

# %%
imdb_movie_data
# Out:
#             Movie_Name  Ratings  Voting_Counts  Durations     Genre
# 0    Kraven the Hunter      5.5          49000        127  Thriller
# 1              Heretic      7.0         127000        111  Thriller
# 2             Twisters      6.5         163000        122  Thriller
# 3             Conclave      7.4         139000          0  Thriller
# 4                 Trap      5.8         134000        105  Thriller
# ..                 ...      ...            ...        ...       ...
# 964   Gentleman Caller      8.5              9        103    Horror
# 965           Cintihar      2.5             11         77    Horror
# 966              Yagna      5.9           1100        131    Horror
# 967     Once Passed On      6.6              6         91    Horror
# 968              Rahha      2.7             13        135    Horror
#
# [5109 rows x 5 columns]

# %%
imdb_movie_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 5109 entries, 0 to 968
# Data columns (total 5 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Movie_Name     5109 non-null   object
#  1   Ratings        5109 non-null   float64
#  2   Voting_Counts  5109 non-null   int64
#  3   Durations      5109 non-null   int64
#  4   Genre          5109 non-null   object
# dtypes: float64(1), int64(2), object(2)
# memory usage: 239.5+ KB

# %%
imdb_movie_data.iloc[4500:5109]
# Out:
#                         Movie_Name  Ratings  Voting_Counts  Durations   Genre
# 360  The Exorcism of Saint Patrick      3.6            162         90  Horror
# 361                        Respati      5.8            279        112  Horror
# 362                  Winter Island      4.6            165        102  Horror
# 363                          Noise      5.9             19         95  Horror
# 364                        Tenants      5.8             79         94  Horror
# ..                             ...      ...            ...        ...     ...
# 964               Gentleman Caller      8.5              9        103  Horror
# 965                       Cintihar      2.5             11         77  Horror
# 966                          Yagna      5.9           1100        131  Horror
# 967                 Once Passed On      6.6              6         91  Horror
# 968                          Rahha      2.7             13        135  Horror
#
# [609 rows x 5 columns]

# %%
imdb_movie_data_2024
# Out:
#              Movie_Name  Ratings  Voting_Counts  Durations     Genre
# 0     Kraven the Hunter      5.5          49000        127  Thriller
# 1               Heretic      7.0         127000        111  Thriller
# 2              Twisters      6.5         163000        122  Thriller
# 3              Conclave      7.4         139000          0  Thriller
# 4                  Trap      5.8         134000        105  Thriller
# ...                 ...      ...            ...        ...       ...
# 5104   Gentleman Caller      8.5              9        103    Horror
# 5105           Cintihar      2.5             11         77    Horror
# 5106              Yagna      5.9           1100        131    Horror
# 5107     Once Passed On      6.6              6         91    Horror
# 5108              Rahha      2.7             13        135    Horror
#
# [5109 rows x 5 columns]

# %%
imdb_movie_data_2024.tail()0
# Out:
#             Movie_Name  Ratings  Voting_Counts  Durations   Genre
# 5104  Gentleman Caller      8.5              9        103  Horror
# 5105          Cintihar      2.5             11         77  Horror
# 5106             Yagna      5.9           1100        131  Horror
# 5107    Once Passed On      6.6              6         91  Horror
# 5108             Rahha      2.7             13        135  Horror

# %%
imdb_movie_data_2024.isnull().sum()
# Out:
# Movie_Name       0
# Ratings          0
# Voting_Counts    0
# Durations        0
# Genre            0
# dtype: int64

# %%
imdb_movie_data_2024.duplicated().sum()
# Out:
# 0

# %%
imdb_movie_data_2024.to_csv('imdb_movie_datas_2024.csv',index=False)

# %%
d=pd.read_csv('imdb_movie_datas_2024.csv')

# %%
d
# Out:
#              Movie_Name  Ratings  Voting_Counts  Durations     Genre
# 0     Kraven the Hunter      5.5          49000        127  Thriller
# 1               Heretic      7.0         127000        111  Thriller
# 2              Twisters      6.5         163000        122  Thriller
# 3              Conclave      7.4         139000          0  Thriller
# 4                  Trap      5.8         134000        105  Thriller
# ...                 ...      ...            ...        ...       ...
# 5104   Gentleman Caller      8.5              9        103    Horror
# 5105           Cintihar      2.5             11         77    Horror
# 5106              Yagna      5.9           1100        131    Horror
# 5107     Once Passed On      6.6              6         91    Horror
# 5108              Rahha      2.7             13        135    Horror
#
# [5109 rows x 5 columns]

# %%
d.head(20)
# Out:
#                    Movie_Name  Ratings  Voting_Counts  Durations     Genre
# 0           Kraven the Hunter      5.5          49000        127  Thriller
# 1                     Heretic      7.0         127000        111  Thriller
# 2                    Twisters      6.5         163000        122  Thriller
# 3                    Conclave      7.4         139000        120  Thriller
# 4                        Trap      5.8         134000        105  Thriller
# 5                    Babygirl      6.0          50000        114  Thriller
# 6       Venom: The Last Dance      6.0         112000        110  Thriller
# 7                    Longlegs      6.6         181000        101  Thriller
# 8   Pushpa: The Rule - Part 2      6.1          55000        201  Thriller
# 9                    Presence      6.1          19000         84  Thriller
# 10                Blink Twice      6.5         103000        102  Thriller
# ...

# %%
d.to_csv('imdb_movie_datas_2024.csv',index=False)

# %%
da=pd.read_csv('imdb_movie_datas_2024.csv')

# %%
da
# Out:
#              Movie_Name  Ratings  Voting_Counts  Durations     Genre
# 0     Kraven the Hunter      5.5          49000        127  Thriller
# 1               Heretic      7.0         127000        111  Thriller
# 2              Twisters      6.5         163000        122  Thriller
# 3              Conclave      7.4         139000        120  Thriller
# 4                  Trap      5.8         134000        105  Thriller
# ...                 ...      ...            ...        ...       ...
# 5104   Gentleman Caller      8.5              9        103    Horror
# 5105           Cintihar      2.5             11         77    Horror
# 5106              Yagna      5.9           1100        131    Horror
# 5107     Once Passed On      6.6              6         91    Horror
# 5108              Rahha      2.7             13        135    Horror
#
# [5109 rows x 5 columns]

# %%
da.head(20)
# Out:
#                    Movie_Name  Ratings  Voting_Counts  Durations     Genre
# 0           Kraven the Hunter      5.5          49000        127  Thriller
# 1                     Heretic      7.0         127000        111  Thriller
# 2                    Twisters      6.5         163000        122  Thriller
# 3                    Conclave      7.4         139000        120  Thriller
# 4                        Trap      5.8         134000        105  Thriller
# 5                    Babygirl      6.0          50000        114  Thriller
# 6       Venom: The Last Dance      6.0         112000        110  Thriller
# 7                    Longlegs      6.6         181000        101  Thriller
# 8   Pushpa: The Rule - Part 2      6.1          55000        201  Thriller
# 9                    Presence      6.1          19000         84  Thriller
# 10                Blink Twice      6.5         103000        102  Thriller
# ...
