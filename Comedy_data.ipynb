# %%
from selenium import webdriver
from selenium.webdriver.common.by import By
from selenium.webdriver.common.action_chains import ActionChains
import time
import pandas as pd

driver=webdriver.Chrome()

driver.get('https://www.imdb.com/search/title/?title_type=feature&release_date=2024-01-01,2024-12-31&genres=comedy')

time.sleep(4)

def click_load_more():
    try:
        load_more_button=driver.find_element(By.XPATH,'//*[@id="__next"]/main/div[2]/div[3]/section/section/div/section/section/div[2]/div/section/div[2]/div[2]/div[2]/div/span/button/span/span')
        ActionChains(driver).move_to_element(load_more_button).perform()

        load_more_button.click()
        time.sleep(3)
        return True
    except Exception as e:
        print(f"Erorr the moive:{e}")
        return False

while click_load_more():
    print('clicked "load more" button')

print("no more content the page load")
# Out:
# clicked "load more" button
# clicked "load more" button
# clicked "load more" button
# clicked "load more" button
# clicked "load more" button
# clicked "load more" button
# clicked "load more" button
# clicked "load more" button
# clicked "load more" button
# clicked "load more" button
# clicked "load more" button
# clicked "load more" button
# clicked "load more" button
# clicked "load more" button
# clicked "load more" button
# clicked "load more" button
# clicked "load more" button
# clicked "load more" button
# clicked "load more" button
# clicked "load more" button
# clicked "load more" button
# clicked "load more" button
# clicked "load more" button
# clicked "load more" button
# clicked "load more" button
# clicked "load more" button
# clicked "load more" button
# clicked "load more" button
# clicked "load more" button
# clicked "load more" button
# ...

# %%
from selenium import webdriver
from selenium.webdriver.common.by import By
import time
import pandas as pd

#driver=webdriver.Chrome()

#url="https://www.imdb.com/search/title/?title_type=feature&release_date=2024-01-01,2024-12-31&genres=action"
#driver.get(url)

time.sleep(4)

movie=[]
ratings=[]
votings=[]
durations=[]

 

movie_data=driver.find_elements(By.XPATH,'//*[@id="__next"]/main/div[2]/div[3]/section/section/div/section/section/div[2]/div/section/div[2]/div[2]/ul/li')

for i in movie_data:
    try:
        moviename=i.find_element(By.XPATH,'./div/div/div/div[1]/div[2]/div[1]/a/h3').text

        rating=i.find_element(By.XPATH,'./div/div/div/div[1]/div[2]/span/div/span/span[1]').text

        voting=i.find_element(By.XPATH,'./div/div/div/div[1]/div[2]/span/div/span/span[2]').text

        duration=i.find_element(By.XPATH,'./div/div/div/div[1]/div[2]/div[2]/span[2]').text

    
        movie.append(moviename)
        ratings.append(rating)
        votings.append(voting)
        durations.append(duration)

    except Exception as e:
        print(f"Erorr the moive:{e}")
        continue

comedy_movie=pd.DataFrame({
    'Movie_Name':movie,
    'Ratings':ratings,
    'Voting_Counts':votings,
    'Durations':durations
})
                    
driver.quit()
comedy_movie
# Out:
# Erorr the moive:Message: no such element: Unable to locate element: {"method":"xpath","selector":"./div/div/div/div[1]/div[2]/span/div/span/span[1]"}
#   (Session info: chrome=134.0.6998.178); For documentation on this error, please visit: https://www.selenium.dev/documentation/webdriver/troubleshooting/errors#no-such-element-exception
# Stacktrace:
# 	GetHandleVerifier [0x00007FF764584C25+3179557]
# 	(No symbol) [0x00007FF7641E88A0]
# 	(No symbol) [0x00007FF7640791CA]
# 	(No symbol) [0x00007FF7640CFA67]
# 	(No symbol) [0x00007FF7640CFC9C]
# 	(No symbol) [0x00007FF7640C240C]
# 	(No symbol) [0x00007FF7640F7C6F]
# 	(No symbol) [0x00007FF7640C22D6]
# 	(No symbol) [0x00007FF7640F7E40]
# 	(No symbol) [0x00007FF7641202F3]
# 	(No symbol) [0x00007FF7640F7A03]
# 	(No symbol) [0x00007FF7640C06D0]
# 	(No symbol) [0x00007FF7640C1983]
# 	GetHandleVerifier [0x00007FF7645E67CD+3579853]
# 	GetHandleVerifier [0x00007FF7645FD1D2+3672530]
# 	GetHandleVerifier [0x00007FF7645F2153+3627347]
# ...

# %%
comedy_movie
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 comedy_movie
#
# NameError: name 'comedy_movie' is not defined

# %%
comedy_movie.shape
# Out:
# (1323, 4)

# %%
comedy_movie['Genre']='Comedy'

# %%
comedy_movie
# Out:
#                           Movie_Name Ratings Voting_Counts Durations   Genre
# 0                           1. Anora     7.5        (168K)    2h 19m  Comedy
# 1                         2. Moana 2     6.6         (95K)    1h 40m  Comedy
# 2                       3. Riff Raff     5.8        (2.2K)    1h 43m  Comedy
# 3            4. Sonic the Hedgehog 3     6.9         (55K)    1h 50m  Comedy
# 4                     5. A Real Pain     7.1         (81K)    1h 30m  Comedy
# ...                              ...     ...           ...       ...     ...
# 1318  1543. Kak ya vstretil eyo mamu     4.3          (41)    1h 29m  Comedy
# 1319                 1545. Trip-Tych     6.9          (28)    1h 20m  Comedy
# 1320              1547. Bhale Unnade     9.0        (3.1K)    2h 17m  Comedy
# 1321      1548. Happy Birthday to Me     8.3          (88)    1h 52m  Comedy
# 1322              1550. Cuadrilátero     7.5           (8)    1h 21m  Comedy
#
# [1323 rows x 5 columns]

# %%
comedy_movie.isnull().sum()
# Out:
# Movie_Name       0
# Ratings          0
# Voting_Counts    0
# Durations        0
# Genre            0
# dtype: int64

# %%
comedy_movie.duplicated().sum()
# Out:
# 0

# %%
comedy_movie.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1323 entries, 0 to 1322
# Data columns (total 5 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Movie_Name     1323 non-null   object
#  1   Ratings        1323 non-null   object
#  2   Voting_Counts  1323 non-null   object
#  3   Durations      1323 non-null   object
#  4   Genre          1323 non-null   object
# dtypes: object(5)
# memory usage: 51.8+ KB

# %%
comedy_movie['Ratings']=pd.to_numeric(comedy_movie['Ratings'],errors='coerce')

# %%
comedy_movie.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1323 entries, 0 to 1322
# Data columns (total 5 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Movie_Name     1323 non-null   object
#  1   Ratings        1323 non-null   float64
#  2   Voting_Counts  1323 non-null   object
#  3   Durations      1323 non-null   object
#  4   Genre          1323 non-null   object
# dtypes: float64(1), object(4)
# memory usage: 51.8+ KB

# %%
comedy_movie.loc[comedy_movie['Ratings'].idxmax()]
# Out:
# Movie_Name       1041. The Premiere
# Ratings                        10.0
# Voting_Counts                   (8)
# Durations                    1h 46m
# Genre                        Comedy
# Name: 938, dtype: object

# %%
comedy_movie
# Out:
#                           Movie_Name  Ratings Voting_Counts Durations   Genre
# 0                           1. Anora      7.5        (168K)    2h 19m  Comedy
# 1                         2. Moana 2      6.6         (95K)    1h 40m  Comedy
# 2                       3. Riff Raff      5.8        (2.2K)    1h 43m  Comedy
# 3            4. Sonic the Hedgehog 3      6.9         (55K)    1h 50m  Comedy
# 4                     5. A Real Pain      7.1         (81K)    1h 30m  Comedy
# ...                              ...      ...           ...       ...     ...
# 1318  1543. Kak ya vstretil eyo mamu      4.3          (41)    1h 29m  Comedy
# 1319                 1545. Trip-Tych      6.9          (28)    1h 20m  Comedy
# 1320              1547. Bhale Unnade      9.0        (3.1K)    2h 17m  Comedy
# 1321      1548. Happy Birthday to Me      8.3          (88)    1h 52m  Comedy
# 1322              1550. Cuadrilátero      7.5           (8)    1h 21m  Comedy
#
# [1323 rows x 5 columns]

# %%
import pandas as pd
comedy=pd.read_csv('Comedy_movie_data.csv')

# %%
comedy
# Out:
#       Unnamed: 0                      Movie_Name  Ratings Voting_Counts  \
# 0              0                        1. Anora      7.5        (168K)
# 1              1                      2. Moana 2      6.6         (95K)
# 2              2                    3. Riff Raff      5.8        (2.2K)
# 3              3         4. Sonic the Hedgehog 3      6.9         (55K)
# 4              4                  5. A Real Pain      7.1         (81K)
# ...          ...                             ...      ...           ...
# 1318        1318  1543. Kak ya vstretil eyo mamu      4.3          (41)
# 1319        1319                 1545. Trip-Tych      6.9          (28)
# 1320        1320              1547. Bhale Unnade      9.0        (3.1K)
# 1321        1321      1548. Happy Birthday to Me      8.3          (88)
# 1322        1322              1550. Cuadrilátero      7.5           (8)
#
#      Durations   Genre
# 0       2h 19m  Comedy
# 1       1h 40m  Comedy
# 2       1h 43m  Comedy
# ...

# %%
comedy.drop(columns='Unnamed: 0')
# Out:
#                           Movie_Name  Ratings Voting_Counts Durations   Genre
# 0                           1. Anora      7.5        (168K)    2h 19m  Comedy
# 1                         2. Moana 2      6.6         (95K)    1h 40m  Comedy
# 2                       3. Riff Raff      5.8        (2.2K)    1h 43m  Comedy
# 3            4. Sonic the Hedgehog 3      6.9         (55K)    1h 50m  Comedy
# 4                     5. A Real Pain      7.1         (81K)    1h 30m  Comedy
# ...                              ...      ...           ...       ...     ...
# 1318  1543. Kak ya vstretil eyo mamu      4.3          (41)    1h 29m  Comedy
# 1319                 1545. Trip-Tych      6.9          (28)    1h 20m  Comedy
# 1320              1547. Bhale Unnade      9.0        (3.1K)    2h 17m  Comedy
# 1321      1548. Happy Birthday to Me      8.3          (88)    1h 52m  Comedy
# 1322              1550. Cuadrilátero      7.5           (8)    1h 21m  Comedy
#
# [1323 rows x 5 columns]

# %%
comedy['Voting_Counts'].unique()
# Out:
# array([' (168K)', ' (95K)', ' (2.2K)', ' (55K)', ' (81K)', ' (3.2K)',
#        ' (484K)', ' (133K)', ' (86K)', ' (18K)', ' (46K)', ' (218K)',
#        ' (153K)', ' (29K)', ' (11K)', ' (64K)', ' (1.9K)', ' (145K)',
#        ' (213K)', ' (58K)', ' (28K)', ' (57K)', ' (49K)', ' (238)',
#        ' (72K)', ' (138K)', ' (92K)', ' (38K)', ' (99K)', ' (41K)',
#        ' (404)', ' (12K)', ' (19K)', ' (1.3K)', ' (523)', ' (93K)',
#        ' (17K)', ' (2K)', ' (2.1K)', ' (1.8K)', ' (327)', ' (3.1K)',
#        ' (430)', ' (313)', ' (22K)', ' (707)', ' (23K)', ' (7K)',
#        ' (52K)', ' (37K)', ' (14K)', ' (67K)', ' (2.3K)', ' (6.4K)',
#        ' (36K)', ' (34K)', ' (700)', ' (8.1K)', ' (13K)', ' (24K)',
#        ' (486)', ' (4.8K)', ' (4.4K)', ' (80)', ' (811)', ' (1.2K)',
#        ' (7.1K)', ' (5K)', ' (35K)', ' (5.6K)', ' (4.3K)', ' (42K)',
#        ' (165)', ' (5.7K)', ' (133)', ' (3.8K)', ' (1.4K)', ' (30K)',
#        ' (198)', ' (145)', ' (3.6K)', ' (2.4K)', ' (159)', ' (776)',
# ...
