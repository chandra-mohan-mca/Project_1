# %%
import pandas as pd

# %%
adventure_datas=pd.read_csv('Adventure_movie_data.csv')

# %%
adventure_datas
# Out:
#      Unnamed: 0                                         Movie_Name  Ratings  \
# 0             0                           1. Mufasa: The Lion King      6.6
# 1             1                                         2. Moana 2      6.6
# 2             2                                            3. Flow      7.9
# 3             3                                        4. Twisters      6.5
# 4             4                                    5. Gladiator II      6.5
# ..          ...                                                ...      ...
# 266         266                                  294. Benjamin Bat      8.1
# 267         267                                         297. Z-Mom      4.7
# 268         268                             298. Mesken (Messuage)      7.5
# 269         269                          299. Rocky and Bullwinkle      9.1
# 270         270  300. Dikkie Dik 2: Een Nieuwe Vriend voor Dikk...      7.4
#
#     Voting_Counts Durations      Genre
# ...

# %%
adventure_datas['Voting_Counts'] = adventure_datas['Voting_Counts'].replace({'[()]': ''}, regex=True)

# %%
adventure_datas
# Out:
#      Unnamed: 0                                         Movie_Name  Ratings  \
# 0             0                           1. Mufasa: The Lion King      6.6
# 1             1                                         2. Moana 2      6.6
# 2             2                                            3. Flow      7.9
# 3             3                                        4. Twisters      6.5
# 4             4                                    5. Gladiator II      6.5
# ..          ...                                                ...      ...
# 266         266                                  294. Benjamin Bat      8.1
# 267         267                                         297. Z-Mom      4.7
# 268         268                             298. Mesken (Messuage)      7.5
# 269         269                          299. Rocky and Bullwinkle      9.1
# 270         270  300. Dikkie Dik 2: Een Nieuwe Vriend voor Dikk...      7.4
#
#     Voting_Counts Durations      Genre
# ...

# %%
adventure_datas['Voting_Counts'] = adventure_datas['Voting_Counts'].apply(
    lambda x: float(x.replace('K', '').replace('k', '')) * 1000 if 'K' in x or 'k' in x else x
)

# %%
adventure_datas
# Out:
#      Unnamed: 0                                         Movie_Name  Ratings  \
# 0             0                           1. Mufasa: The Lion King      6.6
# 1             1                                         2. Moana 2      6.6
# 2             2                                            3. Flow      7.9
# 3             3                                        4. Twisters      6.5
# 4             4                                    5. Gladiator II      6.5
# ..          ...                                                ...      ...
# 266         266                                  294. Benjamin Bat      8.1
# 267         267                                         297. Z-Mom      4.7
# 268         268                             298. Mesken (Messuage)      7.5
# 269         269                          299. Rocky and Bullwinkle      9.1
# 270         270  300. Dikkie Dik 2: Een Nieuwe Vriend voor Dikk...      7.4
#
#     Voting_Counts Durations      Genre
# ...

# %%
adventure_datas['Voting_Counts']=adventure_datas['Voting_Counts'].astype(int)

# %%
adventure_datas
# Out:
#      Unnamed: 0                                         Movie_Name  Ratings  \
# 0             0                           1. Mufasa: The Lion King      6.6
# 1             1                                         2. Moana 2      6.6
# 2             2                                            3. Flow      7.9
# 3             3                                        4. Twisters      6.5
# 4             4                                    5. Gladiator II      6.5
# ..          ...                                                ...      ...
# 266         266                                  294. Benjamin Bat      8.1
# 267         267                                         297. Z-Mom      4.7
# 268         268                             298. Mesken (Messuage)      7.5
# 269         269                          299. Rocky and Bullwinkle      9.1
# 270         270  300. Dikkie Dik 2: Een Nieuwe Vriend voor Dikk...      7.4
#
#      Voting_Counts Durations      Genre
# ...

# %%
adventure_datas.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 271 entries, 0 to 270
# Data columns (total 6 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Unnamed: 0     271 non-null    int64
#  1   Movie_Name     271 non-null    object
#  2   Ratings        271 non-null    float64
#  3   Voting_Counts  271 non-null    int32
#  4   Durations      271 non-null    object
#  5   Genre          271 non-null    object
# dtypes: float64(1), int32(1), int64(1), object(3)
# memory usage: 11.8+ KB

# %%
adventure_datas['Voting_Counts']
# Out:
# 0       54000
# 1       95000
# 2       66000
# 3      163000
# 4      221000
#         ...
# 266        28
# 267        43
# 268        37
# 269        12
# 270        72
# Name: Voting_Counts, Length: 271, dtype: int32

# %%
import re

# %%
import pandas as pd
import re

# Sample data
#data = {'Duration': ['1h 58m', '2h 58m', '0h 45m', '3h 10m']}
#df = pd.DataFrame(data)

# Function to convert durations to minutes
def convert_to_minutes(Durations):
    hours = 0
    minutes = 0
    # Use regex to extract hours and minutes
    match = re.match(r'(?P<hours>\d+)h (?P<minutes>\d+)m', Durations)
    if match:
        hours = int(match.group('hours'))
        minutes = int(match.group('minutes'))
    # Convert to minutes (1 hour = 60 minutes)
    return hours * 60 + minutes

# Apply the conversion function to the 'Duration' column
adventure_datas['Durations'] = adventure_datas['Durations'].apply(convert_to_minutes)

# %%
adventure_datas
# Out:
#      Unnamed: 0                                         Movie_Name  Ratings  \
# 0             0                           1. Mufasa: The Lion King      6.6
# 1             1                                         2. Moana 2      6.6
# 2             2                                            3. Flow      7.9
# 3             3                                        4. Twisters      6.5
# 4             4                                    5. Gladiator II      6.5
# ..          ...                                                ...      ...
# 266         266                                  294. Benjamin Bat      8.1
# 267         267                                         297. Z-Mom      4.7
# 268         268                             298. Mesken (Messuage)      7.5
# 269         269                          299. Rocky and Bullwinkle      9.1
# 270         270  300. Dikkie Dik 2: Een Nieuwe Vriend voor Dikk...      7.4
#
#      Voting_Counts  Durations      Genre
# ...

# %%
adventure_datas.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 271 entries, 0 to 270
# Data columns (total 6 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Unnamed: 0     271 non-null    int64
#  1   Movie_Name     271 non-null    object
#  2   Ratings        271 non-null    float64
#  3   Voting_Counts  271 non-null    int32
#  4   Durations      271 non-null    int64
#  5   Genre          271 non-null    object
# dtypes: float64(1), int32(1), int64(2), object(2)
# memory usage: 11.8+ KB

# %%
adventure_datas['Movie_Name'] = adventure_datas['Movie_Name'].replace(r'^\d+\.\s*', '', regex=True)

# %%
adventure_datas
# Out:
#      Unnamed: 0                                       Movie_Name  Ratings  \
# 0             0                            Mufasa: The Lion King      6.6
# 1             1                                          Moana 2      6.6
# 2             2                                             Flow      7.9
# 3             3                                         Twisters      6.5
# 4             4                                     Gladiator II      6.5
# ..          ...                                              ...      ...
# 266         266                                     Benjamin Bat      8.1
# 267         267                                            Z-Mom      4.7
# 268         268                                Mesken (Messuage)      7.5
# 269         269                             Rocky and Bullwinkle      9.1
# 270         270  Dikkie Dik 2: Een Nieuwe Vriend voor Dikkie Dik      7.4
#
#      Voting_Counts  Durations      Genre
# ...

# %%
adventure_datas['Voting_Counts']
# Out:
# 0       54000
# 1       95000
# 2       66000
# 3      163000
# 4      221000
#         ...
# 266        28
# 267        43
# 268        37
# 269        12
# 270        72
# Name: Voting_Counts, Length: 271, dtype: int32

# %%
adventure_datas.loc[adventure_datas['Voting_Counts'].idxmax()]
# Out:
# Unnamed: 0                    9
# Movie_Name       Dune: Part Two
# Ratings                     8.5
# Voting_Counts            617000
# Durations                   166
# Genre                 Adventure
# Name: 9, dtype: object

# %%
adventure_datas.isnull().sum()
# Out:
# Unnamed: 0       0
# Movie_Name       0
# Ratings          0
# Voting_Counts    0
# Durations        0
# Genre            0
# dtype: int64

# %%
adventure_movie=adventure_datas.to_csv('Adventure_movie_datas.csv')

# %%
adventure_movie=adventure_datas.drop(columns='Unnamed: 0')

# %%
adventure_movie
# Out:
#                                           Movie_Name  Ratings  Voting_Counts  \
# 0                              Mufasa: The Lion King      6.6          54000
# 1                                            Moana 2      6.6          95000
# 2                                               Flow      7.9          66000
# 3                                           Twisters      6.5         163000
# 4                                       Gladiator II      6.5         221000
# ..                                               ...      ...            ...
# 266                                     Benjamin Bat      8.1             28
# 267                                            Z-Mom      4.7             43
# 268                                Mesken (Messuage)      7.5             37
# 269                             Rocky and Bullwinkle      9.1             12
# 270  Dikkie Dik 2: Een Nieuwe Vriend voor Dikkie Dik      7.4             72
#
#      Durations      Genre
# ...

# %%
adventure_movie.to_csv('Adventure_movie_datas.csv')
