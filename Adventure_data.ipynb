# %%
from selenium import webdriver
from selenium.webdriver.common.by import By
from selenium.webdriver.common.action_chains import ActionChains
import time
import pandas as pd

driver=webdriver.Chrome()

driver.get('https://www.imdb.com/search/title/?title_type=feature&release_date=2024-01-01,2024-12-31&genres=adventure')

time.sleep(4)

def click_load_more():
    try:
        load_more_button=driver.find_element(By.XPATH,'//*[@id="__next"]/main/div[2]/div[3]/section/section/div/section/section/div[2]/div/section/div[2]/div[2]/div[2]/div/span/button/span/span')
        ActionChains(driver).move_to_element(load_more_button).perform()

        load_more_button.click()
        time.sleep(3)
        return True
    except Exception as e:
        print(f"Erorr the moive:{e}")
        return False

while click_load_more():
    print('clicked "load more" button')

print("no more content the page load")
# Out:
# clicked "load more" button
# clicked "load more" button
# clicked "load more" button
# clicked "load more" button
# clicked "load more" button
# Erorr the moive:Message: no such element: Unable to locate element: {"method":"xpath","selector":"//*[@id="__next"]/main/div[2]/div[3]/section/section/div/section/section/div[2]/div/section/div[2]/div[2]/div[2]/div/span/button/span/span"}
#   (Session info: chrome=134.0.6998.178); For documentation on this error, please visit: https://www.selenium.dev/documentation/webdriver/troubleshooting/errors#no-such-element-exception
# Stacktrace:
# 	GetHandleVerifier [0x00007FF764584C25+3179557]
# 	(No symbol) [0x00007FF7641E88A0]
# 	(No symbol) [0x00007FF7640791CA]
# 	(No symbol) [0x00007FF7640CFA67]
# 	(No symbol) [0x00007FF7640CFC9C]
# 	(No symbol) [0x00007FF764123627]
# 	(No symbol) [0x00007FF7640F7C6F]
# 	(No symbol) [0x00007FF7641202F3]
# 	(No symbol) [0x00007FF7640F7A03]
# 	(No symbol) [0x00007FF7640C06D0]
# 	(No symbol) [0x00007FF7640C1983]
# ...

# %%
from selenium import webdriver
from selenium.webdriver.common.by import By
import time
import pandas as pd

#driver=webdriver.Chrome()

#url="https://www.imdb.com/search/title/?title_type=feature&release_date=2024-01-01,2024-12-31&genres=action"
#driver.get(url)

time.sleep(4)

movie=[]
ratings=[]
votings=[]
durations=[]

 

movie_data=driver.find_elements(By.XPATH,'//*[@id="__next"]/main/div[2]/div[3]/section/section/div/section/section/div[2]/div/section/div[2]/div[2]/ul/li')

for i in movie_data:
    try:
        moviename=i.find_element(By.XPATH,'./div/div/div/div[1]/div[2]/div[1]/a/h3').text

        rating=i.find_element(By.XPATH,'./div/div/div/div[1]/div[2]/span/div/span/span[1]').text

        voting=i.find_element(By.XPATH,'./div/div/div/div[1]/div[2]/span/div/span/span[2]').text

        duration=i.find_element(By.XPATH,'./div/div/div/div[1]/div[2]/div[2]/span[2]').text

    
        movie.append(moviename)
        ratings.append(rating)
        votings.append(voting)
        durations.append(duration)

    except Exception as e:
        print(f"Erorr the moive:{e}")
        continue

adventure_movie=pd.DataFrame({
    'Movie_Name':movie,
    'Ratings':ratings,
    'Voting_Counts':votings,
    'Durations':durations
})
                    
driver.quit()
adventure_movie
# Out:
# Erorr the moive:Message: no such element: Unable to locate element: {"method":"xpath","selector":"./div/div/div/div[1]/div[2]/div[2]/span[2]"}
#   (Session info: chrome=134.0.6998.178); For documentation on this error, please visit: https://www.selenium.dev/documentation/webdriver/troubleshooting/errors#no-such-element-exception
# Stacktrace:
# 	GetHandleVerifier [0x00007FF764584C25+3179557]
# 	(No symbol) [0x00007FF7641E88A0]
# 	(No symbol) [0x00007FF7640791CA]
# 	(No symbol) [0x00007FF7640CFA67]
# 	(No symbol) [0x00007FF7640CFC9C]
# 	(No symbol) [0x00007FF7640C240C]
# 	(No symbol) [0x00007FF7640F7C6F]
# 	(No symbol) [0x00007FF7640C22D6]
# 	(No symbol) [0x00007FF7640F7E40]
# 	(No symbol) [0x00007FF7641202F3]
# 	(No symbol) [0x00007FF7640F7A03]
# 	(No symbol) [0x00007FF7640C06D0]
# 	(No symbol) [0x00007FF7640C1983]
# 	GetHandleVerifier [0x00007FF7645E67CD+3579853]
# 	GetHandleVerifier [0x00007FF7645FD1D2+3672530]
# 	GetHandleVerifier [0x00007FF7645F2153+3627347]
# ...

# %%
adventure_movie
# Out:
#                                             Movie_Name Ratings Voting_Counts  \
# 0                             1. Mufasa: The Lion King     6.6         (54K)
# 1                                           2. Moana 2     6.6         (95K)
# 2                                              3. Flow     7.9         (66K)
# 3                                          4. Twisters     6.5        (163K)
# 4                                      5. Gladiator II     6.5        (221K)
# ..                                                 ...     ...           ...
# 266                                  294. Benjamin Bat     8.1          (28)
# 267                                         297. Z-Mom     4.7          (43)
# 268                             298. Mesken (Messuage)     7.5          (37)
# 269                          299. Rocky and Bullwinkle     9.1          (12)
# 270  300. Dikkie Dik 2: Een Nieuwe Vriend voor Dikk...     7.4          (72)
#
#     Durations
# 0      1h 58m
# ...

# %%
adventure_movie['Ratings']=pd.to_numeric(adventure_movie['Ratings'],errors='coerce')

# %%
adventure_movie.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 271 entries, 0 to 270
# Data columns (total 4 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Movie_Name     271 non-null    object
#  1   Ratings        271 non-null    float64
#  2   Voting_Counts  271 non-null    object
#  3   Durations      271 non-null    object
# dtypes: float64(1), object(3)
# memory usage: 8.6+ KB

# %%
adventure_movie.isnull().sum()
# Out:
# Movie_Name       0
# Ratings          0
# Voting_Counts    0
# Durations        0
# dtype: int64

# %%
adventure_movie['Genre']='Adventure'

# %%
import pandas as pd

# %%
adventures=pd.read_csv('Adventure_movie_data.csv')

# %%
adventures
# Out:
#      Unnamed: 0                                         Movie_Name  Ratings  \
# 0             0                           1. Mufasa: The Lion King      6.6
# 1             1                                         2. Moana 2      6.6
# 2             2                                            3. Flow      7.9
# 3             3                                        4. Twisters      6.5
# 4             4                                    5. Gladiator II      6.5
# ..          ...                                                ...      ...
# 266         266                                  294. Benjamin Bat      8.1
# 267         267                                         297. Z-Mom      4.7
# 268         268                             298. Mesken (Messuage)      7.5
# 269         269                          299. Rocky and Bullwinkle      9.1
# 270         270  300. Dikkie Dik 2: Een Nieuwe Vriend voor Dikk...      7.4
#
#     Voting_Counts Durations      Genre
# ...

# %%
adventure_movies=adventures.drop(columns='Unnamed: 0')

# %%
adventure_movies
# Out:
#                                             Movie_Name  Ratings  \
# 0                             1. Mufasa: The Lion King      6.6
# 1                                           2. Moana 2      6.6
# 2                                              3. Flow      7.9
# 3                                          4. Twisters      6.5
# 4                                      5. Gladiator II      6.5
# ..                                                 ...      ...
# 266                                  294. Benjamin Bat      8.1
# 267                                         297. Z-Mom      4.7
# 268                             298. Mesken (Messuage)      7.5
# 269                          299. Rocky and Bullwinkle      9.1
# 270  300. Dikkie Dik 2: Een Nieuwe Vriend voor Dikk...      7.4
#
#      Voting_Counts Durations      Genre
# 0            54000    1h 58m  Adventure
# 1            95000    1h 40m  Adventure
# 2            66000    1h 25m  Adventure
# ...

# %%
adventure_movies['Voting_Counts'] = adventure_movies['Voting_Counts'].replace({'[()]': ''}, regex=True)

# %%
adventure_movies['Voting_Counts'] = adventure_movies['Voting_Counts'].apply(lambda x: float(x.replace('K', '').replace('k', '')) * 1000)

# %%
adventure_movies
# Out:
#                                             Movie_Name  Ratings  \
# 0                             1. Mufasa: The Lion King      6.6
# 1                                           2. Moana 2      6.6
# 2                                              3. Flow      7.9
# 3                                          4. Twisters      6.5
# 4                                      5. Gladiator II      6.5
# ..                                                 ...      ...
# 266                                  294. Benjamin Bat      8.1
# 267                                         297. Z-Mom      4.7
# 268                             298. Mesken (Messuage)      7.5
# 269                          299. Rocky and Bullwinkle      9.1
# 270  300. Dikkie Dik 2: Een Nieuwe Vriend voor Dikk...      7.4
#
#      Voting_Counts Durations      Genre
# 0          54000.0    1h 58m  Adventure
# 1          95000.0    1h 40m  Adventure
# 2          66000.0    1h 25m  Adventure
# ...

# %%
adventure_movies.head(30)
# Out:
#                                            Movie_Name  Ratings  Voting_Counts  \
# 0                            1. Mufasa: The Lion King      6.6        54000.0
# 1                                          2. Moana 2      6.6        95000.0
# 2                                             3. Flow      7.9        66000.0
# 3                                         4. Twisters      6.5       163000.0
# 4                                     5. Gladiator II      6.5       221000.0
# 5                             6. Sonic the Hedgehog 3      6.9        55000.0
# 6                            7. Venom: The Last Dance      6.0       112000.0
# 7   8. The Day the Earth Blew Up: A Looney Tunes M...      7.0         3200.0
# 8                             9. Deadpool & Wolverine      7.6       484000.0
# 9                                  10. Dune: Part Two      8.5       617000.0
# 10                     11. Solo Leveling: ReAwakening      8.8         9800.0
# ...

# %%
adventure_movies['Voting_Counts'] = adventure_movies['Voting_Counts'].astype(int)

# %%
adventures['Voting_Counts']=adventures['Voting_Counts'].astype(int)

# %%
adventure_movies
# Out:
#                                             Movie_Name  Ratings  \
# 0                             1. Mufasa: The Lion King      6.6
# 1                                           2. Moana 2      6.6
# 2                                              3. Flow      7.9
# 3                                          4. Twisters      6.5
# 4                                      5. Gladiator II      6.5
# ..                                                 ...      ...
# 266                                  294. Benjamin Bat      8.1
# 267                                         297. Z-Mom      4.7
# 268                             298. Mesken (Messuage)      7.5
# 269                          299. Rocky and Bullwinkle      9.1
# 270  300. Dikkie Dik 2: Een Nieuwe Vriend voor Dikk...      7.4
#
#      Voting_Counts Durations      Genre
# 0            54000    1h 58m  Adventure
# 1            95000    1h 40m  Adventure
# 2            66000    1h 25m  Adventure
# ...

# %%
adventures.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 271 entries, 0 to 270
# Data columns (total 5 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Movie_Name     271 non-null    object
#  1   Ratings        271 non-null    float64
#  2   Voting_Counts  271 non-null    int32
#  3   Durations      271 non-null    object
#  4   Genre          271 non-null    object
# dtypes: float64(1), int32(1), object(3)
# memory usage: 9.7+ KB

# %%
adventures['Voting_Counts']=adventures['Voting_Counts']*1000

# %%
adventures
# Out:
#                                             Movie_Name  Ratings  \
# 0                             1. Mufasa: The Lion King      6.6
# 1                                           2. Moana 2      6.6
# 2                                              3. Flow      7.9
# 3                                          4. Twisters      6.5
# 4                                      5. Gladiator II      6.5
# ..                                                 ...      ...
# 266                                  294. Benjamin Bat      8.1
# 267                                         297. Z-Mom      4.7
# 268                             298. Mesken (Messuage)      7.5
# 269                          299. Rocky and Bullwinkle      9.1
# 270  300. Dikkie Dik 2: Een Nieuwe Vriend voor Dikk...      7.4
#
#      Voting_Counts Durations      Genre
# 0            54000    1h 58m  Adventure
# 1            95000    1h 40m  Adventure
# 2            66000    1h 25m  Adventure
# ...

# %%
adventures['Movie_Name'] = adventures['Movie_Name'].replace(r'^\d+\.\s*', '', regex=True)

# %%
adventures
# Out:
#                                           Movie_Name  Ratings  Voting_Counts  \
# 0                              Mufasa: The Lion King      6.6          54000
# 1                                            Moana 2      6.6          95000
# 2                                               Flow      7.9          66000
# 3                                           Twisters      6.5         163000
# 4                                       Gladiator II      6.5         221000
# ..                                               ...      ...            ...
# 266                                     Benjamin Bat      8.1          28000
# 267                                            Z-Mom      4.7          43000
# 268                                Mesken (Messuage)      7.5          37000
# 269                             Rocky and Bullwinkle      9.1          12000
# 270  Dikkie Dik 2: Een Nieuwe Vriend voor Dikkie Dik      7.4          72000
#
#     Durations      Genre
# ...

# %%
adventures.head(30)
# Out:
#                                          Movie_Name  Ratings  Voting_Counts  \
# 0                             Mufasa: The Lion King      6.6          54000
# 1                                           Moana 2      6.6          95000
# 2                                              Flow      7.9          66000
# 3                                          Twisters      6.5         163000
# 4                                      Gladiator II      6.5         221000
# 5                              Sonic the Hedgehog 3      6.9          55000
# 6                             Venom: The Last Dance      6.0         112000
# 7   The Day the Earth Blew Up: A Looney Tunes Movie      7.0           3000
# 8                              Deadpool & Wolverine      7.6         484000
# 9                                    Dune: Part Two      8.5         617000
# 10                       Solo Leveling: ReAwakening      8.8           9000
# ...

# %%
adventures.to_csv('Adventures_movie_datas.csv')

# %%
adventure_data=pd.read_csv('Adventure_movie_data.csv')

# %%
adventure_data
# Out:
#      Unnamed: 0                                         Movie_Name  Ratings  \
# 0             0                           1. Mufasa: The Lion King      6.6
# 1             1                                         2. Moana 2      6.6
# 2             2                                            3. Flow      7.9
# 3             3                                        4. Twisters      6.5
# 4             4                                    5. Gladiator II      6.5
# ..          ...                                                ...      ...
# 266         266                                  294. Benjamin Bat      8.1
# 267         267                                         297. Z-Mom      4.7
# 268         268                             298. Mesken (Messuage)      7.5
# 269         269                          299. Rocky and Bullwinkle      9.1
# 270         270  300. Dikkie Dik 2: Een Nieuwe Vriend voor Dikk...      7.4
#
#     Voting_Counts Durations      Genre
# ...

# %%
adventure_data['Voting_Counts'] = adventure_data['Voting_Counts'].apply(
    lambda x: float(x.replace('K', '').replace('k', '')) * 1000 if 'K' in x or 'k' in x else x
)

# %%
adventure_data['Voting_Counts'] = adventure_data['Voting_Counts'].replace({'[()]': ''}, regex=True)

# %%
adventure_data
# Out:
#      Unnamed: 0                                         Movie_Name  Ratings  \
# 0             0                           1. Mufasa: The Lion King      6.6
# 1             1                                         2. Moana 2      6.6
# 2             2                                            3. Flow      7.9
# 3             3                                        4. Twisters      6.5
# 4             4                                    5. Gladiator II      6.5
# ..          ...                                                ...      ...
# 266         266                                  294. Benjamin Bat      8.1
# 267         267                                         297. Z-Mom      4.7
# 268         268                             298. Mesken (Messuage)      7.5
# 269         269                          299. Rocky and Bullwinkle      9.1
# 270         270  300. Dikkie Dik 2: Een Nieuwe Vriend voor Dikk...      7.4
#
#     Voting_Counts Durations      Genre
# ...

# %%
adventure_data['Voting_Counts']=adventure_data['Voting_Counts'].astype(int)

# %%
adventure_data
# Out:
#      Unnamed: 0                                         Movie_Name  Ratings  \
# 0             0                           1. Mufasa: The Lion King      6.6
# 1             1                                         2. Moana 2      6.6
# 2             2                                            3. Flow      7.9
# 3             3                                        4. Twisters      6.5
# 4             4                                    5. Gladiator II      6.5
# ..          ...                                                ...      ...
# 266         266                                  294. Benjamin Bat      8.1
# 267         267                                         297. Z-Mom      4.7
# 268         268                             298. Mesken (Messuage)      7.5
# 269         269                          299. Rocky and Bullwinkle      9.1
# 270         270  300. Dikkie Dik 2: Een Nieuwe Vriend voor Dikk...      7.4
#
#      Voting_Counts Durations      Genre
# ...

# %%
adventure_data.head(30)
# Out:
#     Unnamed: 0                                         Movie_Name  Ratings  \
# 0            0                           1. Mufasa: The Lion King      6.6
# 1            1                                         2. Moana 2      6.6
# 2            2                                            3. Flow      7.9
# 3            3                                        4. Twisters      6.5
# 4            4                                    5. Gladiator II      6.5
# 5            5                            6. Sonic the Hedgehog 3      6.9
# 6            6                           7. Venom: The Last Dance      6.0
# 7            7  8. The Day the Earth Blew Up: A Looney Tunes M...      7.0
# 8            8                            9. Deadpool & Wolverine      7.6
# 9            9                                 10. Dune: Part Two      8.5
# 10          10                     11. Solo Leveling: ReAwakening      8.8
# ...

# %%
a=adventure_data.drop(columns='Unnamed: 0')

# %%
adventure_data['Movie_Name'] = adventure_data['Movie_Name'].replace(r'^\d+\.\s*', '', regex=True)

# %%
aa=a.copy()

# %%
a
# Out:
#                                           Movie_Name  Ratings  Voting_Counts  \
# 0                              Mufasa: The Lion King      6.6          54000
# 1                                            Moana 2      6.6          95000
# 2                                               Flow      7.9          66000
# 3                                           Twisters      6.5         163000
# 4                                       Gladiator II      6.5         221000
# ..                                               ...      ...            ...
# 266                                     Benjamin Bat      8.1             28
# 267                                            Z-Mom      4.7             43
# 268                                Mesken (Messuage)      7.5             37
# 269                             Rocky and Bullwinkle      9.1             12
# 270  Dikkie Dik 2: Een Nieuwe Vriend voor Dikkie Dik      7.4             72
#
#     Durations      Genre
# ...

# %%
import pandas as pd

# Sample DataFrame with time strings

# Function to convert 'h m' format to timedelta
def time_to_timedelta(Durations):
    # Replace 'h' and 'm' to make it compatible with timedelta
    Durations = Durations.replace('h', ' hours').replace('m', ' minutes')
    # Convert the time string to a timedelta object
    return pd.to_timedelta(Durations)

# Apply the function to convert the time strings to timedelta
a['Durations'] = a['Durations'].apply(time_to_timedelta)

# Show the result

# %%
a
# Out:
#                                           Movie_Name  Ratings  Voting_Counts  \
# 0                              Mufasa: The Lion King      6.6          54000
# 1                                            Moana 2      6.6          95000
# 2                                               Flow      7.9          66000
# 3                                           Twisters      6.5         163000
# 4                                       Gladiator II      6.5         221000
# ..                                               ...      ...            ...
# 266                                     Benjamin Bat      8.1             28
# 267                                            Z-Mom      4.7             43
# 268                                Mesken (Messuage)      7.5             37
# 269                             Rocky and Bullwinkle      9.1             12
# 270  Dikkie Dik 2: Een Nieuwe Vriend voor Dikkie Dik      7.4             72
#
#           Durations      Genre
# ...

# %%
a['Durations'] = a['Durations'].replace({'days':' '}, regex=True)

# %%
a
# Out:
#                                           Movie_Name  Ratings  Voting_Counts  \
# 0                              Mufasa: The Lion King      6.6          54000
# 1                                            Moana 2      6.6          95000
# 2                                               Flow      7.9          66000
# 3                                           Twisters      6.5         163000
# 4                                       Gladiator II      6.5         221000
# ..                                               ...      ...            ...
# 266                                     Benjamin Bat      8.1             28
# 267                                            Z-Mom      4.7             43
# 268                                Mesken (Messuage)      7.5             37
# 269                             Rocky and Bullwinkle      9.1             12
# 270  Dikkie Dik 2: Een Nieuwe Vriend voor Dikkie Dik      7.4             72
#
#           Durations      Genre
# ...

# %%
a.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 271 entries, 0 to 270
# Data columns (total 5 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Movie_Name     271 non-null    object
#  1   Ratings        271 non-null    float64
#  2   Voting_Counts  271 non-null    int32
#  3   Durations      271 non-null    timedelta64[ns]
#  4   Genre          271 non-null    object
# dtypes: float64(1), int32(1), object(2), timedelta64[ns](1)
# memory usage: 9.7+ KB

# %%
import pandas as pd

# Sample DataFrame with time strings

# Function to convert 'h m' format to timedelta
def time_to_timedelta(Durations):
    # Replace 'h' and 'm' to make it compatible with timedelta
    Durations = Durations.replace('h', ' hours').replace('m', ' minutes')
    # Convert the time string to a timedelta object
    return pd.to_timedelta(Durations)

# Apply the function to convert the time strings to timedelta
aa['Durations'] = aa['Durations'].apply(time_to_timedelta)

# Extract the time (without days)
aa['Durations'] = aa['Durations'].apply(lambda x: pd.to_datetime(x).time())

# Show the result
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[143], line 16
#      13 aa['Durations'] = aa['Durations'].apply(time_to_timedelta)
#      15 # Extract the time (without days)
# ---> 16 aa['Durations'] = aa['Durations'].apply(lambda x: pd.to_datetime(x).time())
#
# File ~\anaconda3\Lib\site-packages\pandas\core\series.py:4924, in Series.apply(self, func, convert_dtype, args, by_row, **kwargs)
#    4789 def apply(
#    4790     self,
#    4791     func: AggFuncType,
#    (...)
#    4796     **kwargs,
#    4797 ) -> DataFrame | Series:
#    4798     """
#    4799     Invoke function on values of Series.
#    4800
#    (...)
#    4915     dtype: float64
#    4916     """
#    4917     return SeriesApply(
#    4918         self,
#    4919         func,
#    4920         convert_dtype=convert_dtype,
#    4921         by_row=by_row,
#    4922         args=args,
# ...

# %%
aa
# Out:
#                                           Movie_Name  Ratings  Voting_Counts  \
# 0                              Mufasa: The Lion King      6.6          54000
# 1                                            Moana 2      6.6          95000
# 2                                               Flow      7.9          66000
# 3                                           Twisters      6.5         163000
# 4                                       Gladiator II      6.5         221000
# ..                                               ...      ...            ...
# 266                                     Benjamin Bat      8.1             28
# 267                                            Z-Mom      4.7             43
# 268                                Mesken (Messuage)      7.5             37
# 269                             Rocky and Bullwinkle      9.1             12
# 270  Dikkie Dik 2: Een Nieuwe Vriend voor Dikkie Dik      7.4             72
#
#     Durations      Genre
# ...

# %%
aa.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 271 entries, 0 to 270
# Data columns (total 5 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Movie_Name     271 non-null    object
#  1   Ratings        271 non-null    float64
#  2   Voting_Counts  271 non-null    int32
#  3   Durations      271 non-null    timedelta64[ns]
#  4   Genre          271 non-null    object
# dtypes: float64(1), int32(1), object(2), timedelta64[ns](1)
# memory usage: 9.7+ KB

# %%
adventure=pd.read_csv('Adventure_movie_data.csv')

# %%
adventure
# Out:
#      Unnamed: 0                                         Movie_Name  Ratings  \
# 0             0                           1. Mufasa: The Lion King      6.6
# 1             1                                         2. Moana 2      6.6
# 2             2                                            3. Flow      7.9
# 3             3                                        4. Twisters      6.5
# 4             4                                    5. Gladiator II      6.5
# ..          ...                                                ...      ...
# 266         266                                  294. Benjamin Bat      8.1
# 267         267                                         297. Z-Mom      4.7
# 268         268                             298. Mesken (Messuage)      7.5
# 269         269                          299. Rocky and Bullwinkle      9.1
# 270         270  300. Dikkie Dik 2: Een Nieuwe Vriend voor Dikk...      7.4
#
#     Voting_Counts Durations      Genre
# ...

# %%
adventure.drop(columns='Unnamed: 0')
# Out:
#                                             Movie_Name  Ratings Voting_Counts  \
# 0                             1. Mufasa: The Lion King      6.6         (54K)
# 1                                           2. Moana 2      6.6         (95K)
# 2                                              3. Flow      7.9         (66K)
# 3                                          4. Twisters      6.5        (163K)
# 4                                      5. Gladiator II      6.5        (221K)
# ..                                                 ...      ...           ...
# 266                                  294. Benjamin Bat      8.1          (28)
# 267                                         297. Z-Mom      4.7          (43)
# 268                             298. Mesken (Messuage)      7.5          (37)
# 269                          299. Rocky and Bullwinkle      9.1          (12)
# 270  300. Dikkie Dik 2: Een Nieuwe Vriend voor Dikk...      7.4          (72)
#
#     Durations      Genre
# ...

# %%
adventure['Voting_Counts'] = adventure['Voting_Counts'].replace({'[()]': ''}, regex=True)

# %%
adventure
# Out:
#      Unnamed: 0                                         Movie_Name  Ratings  \
# 0             0                           1. Mufasa: The Lion King      6.6
# 1             1                                         2. Moana 2      6.6
# 2             2                                            3. Flow      7.9
# 3             3                                        4. Twisters      6.5
# 4             4                                    5. Gladiator II      6.5
# ..          ...                                                ...      ...
# 266         266                                  294. Benjamin Bat      8.1
# 267         267                                         297. Z-Mom      4.7
# 268         268                             298. Mesken (Messuage)      7.5
# 269         269                          299. Rocky and Bullwinkle      9.1
# 270         270  300. Dikkie Dik 2: Een Nieuwe Vriend voor Dikk...      7.4
#
#     Voting_Counts Durations      Genre
# ...

# %%
adventure['Voting_Counts'] = adventure['Voting_Counts'].apply(
    lambda x: float(x.replace('K', '').replace('k', '')) * 1000 if 'K' in x or 'k' in x else x
)

# %%
adventure
# Out:
#      Unnamed: 0                                         Movie_Name  Ratings  \
# 0             0                           1. Mufasa: The Lion King      6.6
# 1             1                                         2. Moana 2      6.6
# 2             2                                            3. Flow      7.9
# 3             3                                        4. Twisters      6.5
# 4             4                                    5. Gladiator II      6.5
# ..          ...                                                ...      ...
# 266         266                                  294. Benjamin Bat      8.1
# 267         267                                         297. Z-Mom      4.7
# 268         268                             298. Mesken (Messuage)      7.5
# 269         269                          299. Rocky and Bullwinkle      9.1
# 270         270  300. Dikkie Dik 2: Een Nieuwe Vriend voor Dikk...      7.4
#
#     Voting_Counts Durations      Genre
# ...

# %%
adventure['Voting_Counts']=adventure['Voting_Counts'].astype(int)

# %%
adventure
# Out:
#      Unnamed: 0                                         Movie_Name  Ratings  \
# 0             0                           1. Mufasa: The Lion King      6.6
# 1             1                                         2. Moana 2      6.6
# 2             2                                            3. Flow      7.9
# 3             3                                        4. Twisters      6.5
# 4             4                                    5. Gladiator II      6.5
# ..          ...                                                ...      ...
# 266         266                                  294. Benjamin Bat      8.1
# 267         267                                         297. Z-Mom      4.7
# 268         268                             298. Mesken (Messuage)      7.5
# 269         269                          299. Rocky and Bullwinkle      9.1
# 270         270  300. Dikkie Dik 2: Een Nieuwe Vriend voor Dikk...      7.4
#
#      Voting_Counts Durations      Genre
# ...

# %%
import pandas as pd

# Sample DataFrame with time strings

# Function to convert 'h m' format to timedelta
def time_to_timedelta(Durations):
    # Replace 'h' and 'm' to make it compatible with timedelta
    Durations = Durations.replace('h', ' hours').replace('m', ' minutes')
    # Convert the time string to a timedelta object
    return pd.to_timedelta(Durations)

# Apply the function to convert the time strings to timedelta
adventure['Durations'] = adventure['Durations'].apply(time_to_timedelta)

# Extract the time (without days)
adventure['Durations'] = adventure['Durations'].apply(lambda x: pd.to_datetime(x).time())

# Show the result
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[165], line 16
#      13 adventure['Durations'] = adventure['Durations'].apply(time_to_timedelta)
#      15 # Extract the time (without days)
# ---> 16 adventure['Durations'] = adventure['Durations'].apply(lambda x: pd.to_datetime(x).time())
#
# File ~\anaconda3\Lib\site-packages\pandas\core\series.py:4924, in Series.apply(self, func, convert_dtype, args, by_row, **kwargs)
#    4789 def apply(
#    4790     self,
#    4791     func: AggFuncType,
#    (...)
#    4796     **kwargs,
#    4797 ) -> DataFrame | Series:
#    4798     """
#    4799     Invoke function on values of Series.
#    4800
#    (...)
#    4915     dtype: float64
#    4916     """
#    4917     return SeriesApply(
#    4918         self,
#    4919         func,
#    4920         convert_dtype=convert_dtype,
#    4921         by_row=by_row,
# ...

# %%
adventure.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 271 entries, 0 to 270
# Data columns (total 6 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Unnamed: 0     271 non-null    int64
#  1   Movie_Name     271 non-null    object
#  2   Ratings        271 non-null    float64
#  3   Voting_Counts  271 non-null    int32
#  4   Durations      271 non-null    timedelta64[ns]
#  5   Genre          271 non-null    object
# dtypes: float64(1), int32(1), int64(1), object(2), timedelta64[ns](1)
# memory usage: 11.8+ KB
